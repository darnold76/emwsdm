# %%
import psycopg2

conn = psycopg2.connect("user=mapdata password=m0repr4ctic3 host=localhost port=5433")

current_location = conn.cursor()

current_location.execute("SELECT * FROM sbucks LIMIT 100;")
# Out:
# (2, 6, 'Exchange Square', 22.28393936, 114.1581879, '0101000020E6100000121A1C80E88C5C40E90AD71F38573640')
# (24, 61, 'Deira City Center Mall', 25.25411987, 55.33132172, '0101000020E6100000121A1C80E88C5C40E90AD71F38573640')
# (25, 62, 'Bukhatir Tower', 25.3342762, 55.37586212, '0101000020E6100000121A1C80E88C5C40E90AD71F38573640')
# (26, 63, 'Sahara Center', 25.29821968, 55.37155914, '0101000020E6100000121A1C80E88C5C40E90AD71F38573640')
# (27, 64, 'Mega Mall', 25.34505081, 55.39789963, '0101000020E6100000121A1C80E88C5C40E90AD71F38573640')
# (28, 65, 'American University of Sharjah', 25.29776955, 55.48414993, '0101000020E6100000121A1C80E88C5C40E90AD71F38573640')
# (29, 70, 'Uptown Mirdif', 25.22542, 55.42552185, '0101000020E6100000121A1C80E88C5C40E90AD71F38573640')
# (30, 71, 'Al Wahda Mall', 24.47133064, 54.37234116, '0101000020E6100000121A1C80E88C5C40E90AD71F38573640')
# (31, 72, 'Sahara Tower', 24.92459297, 54.99717712, '0101000020E6100000121A1C80E88C5C40E90AD71F38573640')
# ...
